# %%
import pandas as pd
import numpy as np

# %%
customer_df1 = pd.read_csv('Data/file1.csv')

# %%
customer_df2 = pd.read_csv('Data/file2.csv')

# %%
customer_df3 = pd.read_csv('Data/file3.csv')

# %%
customer_df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
customer_df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
customer_df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
def change_columns_headers(df):
    '''enter dataframe as variable'''
    df.columns = df.columns.str.lower()
    return df

# %%
def change_column_name(df, column_old_name, column_new_name):
    return df.rename(columns={column_old_name:column_new_name},inplace=True)

# %%
change_columns_headers(customer_df1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
change_columns_headers(customer_df2)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
change_columns_headers(customer_df3)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
change_column_name(customer_df1,'st','state')

# %%
change_column_name(customer_df2,'st','state')

# %%
customer_df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def rearange_columns(df,list_of_new_column_names):
    '''as second argument put a list of new column names'''
    df = df[list_of_new_column_names]
    return df

# %%
new_column_names = list(customer_df1.columns)

# %%
new_column_names
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
customer_df2 = rearange_columns(customer_df2,new_column_names)
customer_df2
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df3 = rearange_columns(customer_df3,new_column_names)
customer_df3
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
customer_df = pd.concat([customer_df1,customer_df2,customer_df3])
customer_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def drop_column(df,column_name):
    df.drop(columns=[column_name], inplace=True)
    return df

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
customer_df.iloc[1,3].isdigit()
# Out:
# False

# %%
print(customer_df.iloc[1,3])
# Out:
# Bachelor

# %%
customer_df['customer lifetime value']=customer_df['customer lifetime value'].replace({'%': ''}, regex=True)

# %%
customer_df['customer lifetime value'] = pd.to_numeric(customer_df['customer lifetime value'], errors='coerce')

# %%
customer_df['customer lifetime value'] = customer_df['customer lifetime value'].round()

# %%
customer_df['customer lifetime value'].isna().sum()
# Out:
# 2944

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   float64
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 1.1+ MB

# %%
customer_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                    697954.0      0.0                  94.0
# 2                   1288743.0  48767.0                 108.0
# ...

# %%
customer_df['number of open complaints'].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
#maybe try to write a function for this: 

customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/0/00',0,regex=True)

# %%
customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/2/00',2,regex=True)

# %%
customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/1/00',1,regex=True)

# %%
customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/3/00',3,regex=True)

# %%
customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/5/00',5,regex=True)

# %%
customer_df['number of open complaints']=customer_df['number of open complaints'].replace('1/4/00',4,regex=True)

# %%
customer_df['number of open complaints'].unique()
# Out:
# array([0, 2, 1, 3, 5, 4, nan], dtype=object)

# %%
customer_df['gender'].value_counts()
# Out:
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
customer_df['gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
customer_df['gender'] = customer_df['gender'].replace({'Femal':'F','female':'F','Male':'M'})

# %%
customer_df['gender'].value_counts(dropna=False)
# Out:
# F      4607
# M      4408
# NaN    3059
# Name: gender, dtype: int64

# %%
customer_df.count()
# Out:
# customer                     9137
# state                        9137
# gender                       9015
# education                    9137
# customer lifetime value      9130
# income                       9137
# monthly premium auto         9137
# number of open complaints    9137
# policy type                  9137
# vehicle class                9137
# total claim amount           9137
# dtype: int64

# %%
customer_df['state'].value_counts(dropna=False)
# Out:
# California    3032
# NaN           2937
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: state, dtype: int64

# %%
customer_df['state'] = customer_df['state'].replace({'Cali':'California','AZ':'Arizona','WA':'Washington'})

# %%
customer_df['state'].value_counts(dropna=False)
# Out:
# California    3152
# NaN           2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: state, dtype: int64

# %%
customer_df['education'].value_counts()
# Out:
# Bachelor                2719
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Bachelors                 24
# Name: education, dtype: int64

# %%
customer_df['education'] = customer_df['education'].replace({'Bachelors' : 'Bachelor'})

# %%
customer_df['total claim amount'] = customer_df['total claim amount'].round(2)

# %%
customer_df = customer_df.drop_duplicates()

# %%
drop_column(customer_df,'customer')
# Out:
# /Users/filipmakara2/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                 697954.0
# 2         Nevada      F              Bachelor                1288743.0
# 3     California      M              Bachelor                 764586.0
# 4     Washington      M  High School or Below                 536308.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                  23406.0
# ...

# %%
customer_df['gender'].value_counts(dropna=False)
# Out:
# F      4604
# M      4408
# NaN     123
# Name: gender, dtype: int64

# %%
customer_df['customer lifetime value'].fillna(np.mean(customer_df['customer lifetime value']), inplace=True)
# Out:
# /Users/filipmakara2/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
customer_df['customer lifetime value'] = customer_df['customer lifetime value'].round(0).astype(int)
# Out:
# /var/folders/qw/spw5ptl93b53bn0c_4sqb01m0000gq/T/ipykernel_55512/2479429068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['customer lifetime value'] = customer_df['customer lifetime value'].round(0).astype(int)

# %%
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                   182072
# 1        Arizona      F              Bachelor                   697954
# 2         Nevada      F              Bachelor                  1288743
# 3     California      M              Bachelor                   764586
# 4     Washington      M  High School or Below                   536308
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                    23406
# 7066  California      F               College                     3097
# 7067  California      M              Bachelor                     8164
# 7068  California      M               College                     7524
# 7069  California      M               College                     2612
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['income'].fillna(np.mean(customer_df['income']), inplace=True)
# Out:
# /Users/filipmakara2/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
customer_df['income'] = customer_df['income'].round(0).astype(int)
# Out:
# /var/folders/qw/spw5ptl93b53bn0c_4sqb01m0000gq/T/ipykernel_55512/1676783316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['income'] = customer_df['income'].round(0).astype(int)

# %%
customer_df['monthly premium auto'].fillna(np.mean(customer_df['monthly premium auto']), inplace=True)

# %%
customer_df['monthly premium auto'] = customer_df['monthly premium auto'].round(0).astype(int)
# Out:
# /var/folders/qw/spw5ptl93b53bn0c_4sqb01m0000gq/T/ipykernel_55512/421779307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['monthly premium auto'] = customer_df['monthly premium auto'].round(0).astype(int)

# %%
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                   182072
# 1        Arizona      F              Bachelor                   697954
# 2         Nevada      F              Bachelor                  1288743
# 3     California      M              Bachelor                   764586
# 4     Washington      M  High School or Below                   536308
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                    23406
# 7066  California      F               College                     3097
# 7067  California      M              Bachelor                     8164
# 7068  California      M               College                     7524
# 7069  California      M               College                     2612
#
#       income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df = customer_df.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     washington    NaN                master                   182072
# 1        arizona      f              bachelor                   697954
# 2         nevada      f              bachelor                  1288743
# 3     california      m              bachelor                   764586
# 4     washington      m  high school or below                   536308
# ...          ...    ...                   ...                      ...
# 7065  california      m              bachelor                    23406
# 7066  california      f               college                     3097
# 7067  california      m              bachelor                     8164
# 7068  california      m               college                     7524
# 7069  california      m               college                     2612
#
#       income  monthly premium auto  number of open complaints     policy type  \
# ...

# %%
region_dict = {'california':'west region','oregon':'north west','washington':'east','arizona':'central','nevada':'central'}

customer_df['region'] = customer_df['state'].map(region_dict)
